# %% [markdown]
# # <U>ML PROJECT ON WISCONSIN BREAST CANCER DATABASE</U>

# %% [markdown]
# ## 1.<u>**PROBLEM STATEMENT**</u>:
# We are provided with the "Wisconsin Breast Cancer Database (January 8, 1991)". This data corresponds to cancer patients data and classifies the cancer into malignant and benign. We have to clean the data and prepare it for training and testing followed by applying the best fit model , in order to predict whether the given set of attributes of the data of a patient corresponds to Class Benign(2) or Class Malignant(4).Further, we have to check the accuracy of our model to confirm the accuracy of it's prediction.

# %% [markdown]
# ## 2.<U>DATA INPUT</U> :
# The raw CSV Data File is read using Pandas which is mainly used for data analysis. Pandas allows importing data from various file formats like CSV. The Data had missing headers for every column which has increased the complexity of the data , making it difficult to decipher and since we are using 'Supervised Machine Learning' technique, it is important to add the headers . Therefore, headers were incorporated in the raw Data File using Python and the modified Data File was used, henceforth, in the project.

# %%
import numpy as np
import pandas as pd

# %%
mydata = pd.read_csv("C:/Users/91992/Desktop/BREAST CANCER.csv") #reading the csv file
print("\nOriginal file:")
print(mydata)
mydata
# Out:
# Original file:
#      1000025  5   1  1.1  1.2  2 1.3   3  1.4  1.5  2.1
# 0    1002945  5   4    4    5  7  10   3    2    1    2
# 1    1015425  3   1    1    1  2   2   3    1    1    2
# 2    1016277  6   8    8    1  3   4   3    7    1    2
# 3    1017023  4   1    1    3  2   1   3    1    1    2
# 4    1017122  8  10   10    8  7  10   9    7    1    4
# ..       ... ..  ..  ...  ... ..  ..  ..  ...  ...  ...
# 693   776715  3   1    1    1  3   2   1    1    1    2
# 694   841769  2   1    1    1  2   1   1    1    1    2
# 695   888820  5  10   10    3  7   3   8   10    2    4
# 696   897471  4   8    6    4  3   4  10    6    1    4
# 697   897471  4   8    8    5  4   5  10    4    1    4
#
# [698 rows x 11 columns]
#      1000025  5   1  1.1  1.2  2 1.3   3  1.4  1.5  2.1
# 0    1002945  5   4    4    5  7  10   3    2    1    2
# 1    1015425  3   1    1    1  2   2   3    1    1    2
# 2    1016277  6   8    8    1  3   4   3    7    1    2
# ...

# %% [markdown]
# ### NOTE: Modified Data file is named as :"BREAST CANCER2"

# %%
#Adding header

Header_List = ['Sample code number','Clump Thickness','Uniformity of Cell Size','Uniformity of Cell Shape','Marginal Adhesion','Single Epithelial Cell Size','Bare Nuclei','Bland Chromatin','Normal Nucleoli','Mitoses','Class']

#Converting data frame to csv

mydata.to_csv("C:/Users/91992/Desktop/BREAST CANCER2.csv", header=Header_List, index=False)

#Displaying modified csv file

mydata2 = pd.read_csv("C:/Users/91992/Desktop/BREAST CANCER2.csv")
print('\nModified file:') 
print(mydata2) 
mydata2
# Out:
# Modified file:
#      Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 0               1002945                5                        4
# 1               1015425                3                        1
# 2               1016277                6                        8
# 3               1017023                4                        1
# 4               1017122                8                       10
# ..                  ...              ...                      ...
# 693              776715                3                        1
# 694              841769                2                        1
# 695              888820                5                       10
# 696              897471                4                        8
# 697              897471                4                        8
#
#      Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# ...

# %% [markdown]
# ## 3.<U>EXPLORATORY DATA ANALYSIS</U>:
# After the Data File is modified, we will go through the entire Data File and check the information present in each cell. This will help us to know if there is any null values or missing values present in the Data File ; any error in the datatype of the values ; the values are not aligned or present under the correct column name. We will use Graphical as well as Non-Graphical method to perform EDA.

# %% [markdown]
# ### <U>NON-GRAPHICAL EDA</U>:

# %%
#Checking the datatypes of all the columns of the dataframe(using the modified dataframe)

mydata2 = pd.read_csv("C:/Users/91992/Desktop/BREAST CANCER2.csv")

#Check the datatypes of all the columns of the dataframe

mydata2.dtypes
# Out:
# Sample code number              int64
# Clump Thickness                 int64
# Uniformity of Cell Size         int64
# Uniformity of Cell Shape        int64
# Marginal Adhesion               int64
# Single Epithelial Cell Size     int64
# Bare Nuclei                    object
# Bland Chromatin                 int64
# Normal Nucleoli                 int64
# Mitoses                         int64
# Class                           int64
# dtype: object

# %%
mydata2.tail()
# Out:
#      Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 693              776715                3                        1
# 694              841769                2                        1
# 695              888820                5                       10
# 696              897471                4                        8
# 697              897471                4                        8
#
#      Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 693                         1                  1                            3
# 694                         1                  1                            2
# 695                        10                  3                            7
# 696                         6                  4                            3
# 697                         8                  5                            4
#
#     Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses  Class
# ...

# %%
mydata2.shape
# Out:
# (698, 11)

# %%
mydata2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 698 entries, 0 to 697
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Sample code number           698 non-null    int64
#  1   Clump Thickness              698 non-null    int64
#  2   Uniformity of Cell Size      698 non-null    int64
#  3   Uniformity of Cell Shape     698 non-null    int64
#  4   Marginal Adhesion            698 non-null    int64
#  5   Single Epithelial Cell Size  698 non-null    int64
#  6   Bare Nuclei                  698 non-null    object
#  7   Bland Chromatin              698 non-null    int64
#  8   Normal Nucleoli              698 non-null    int64
#  9   Mitoses                      698 non-null    int64
#  10  Class                        698 non-null    int64
# dtypes: int64(10), object(1)
# memory usage: 60.1+ KB

# %%
mydata2.head()
# Out:
#    Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 0             1002945                5                        4
# 1             1015425                3                        1
# 2             1016277                6                        8
# 3             1017023                4                        1
# 4             1017122                8                       10
#
#    Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                         4                  5                            7
# 1                         1                  1                            2
# 2                         8                  1                            3
# 3                         1                  3                            2
# 4                        10                  8                            7
#
#   Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses  Class
# ...

# %%
mydata2.describe()
# Out:
#        Sample code number  Clump Thickness  Uniformity of Cell Size  \
# count        6.980000e+02       698.000000               698.000000
# mean         1.071807e+06         4.416905                 3.137536
# std          6.175323e+05         2.817673                 3.052575
# min          6.163400e+04         1.000000                 1.000000
# 25%          8.702582e+05         2.000000                 1.000000
# 50%          1.171710e+06         4.000000                 1.000000
# 75%          1.238354e+06         6.000000                 5.000000
# max          1.345435e+07        10.000000                10.000000
#
#        Uniformity of Cell Shape  Marginal Adhesion  \
# count                698.000000         698.000000
# mean                   3.210602           2.809456
# std                    2.972867           2.856606
# min                    1.000000           1.000000
# 25%                    1.000000           1.000000
# ...

# %%
#Checking the number of null values in each and every column

mydata2.isnull().sum()
# Out:
# Sample code number             0
# Clump Thickness                0
# Uniformity of Cell Size        0
# Uniformity of Cell Shape       0
# Marginal Adhesion              0
# Single Epithelial Cell Size    0
# Bare Nuclei                    0
# Bland Chromatin                0
# Normal Nucleoli                0
# Mitoses                        0
# Class                          0
# dtype: int64

# %%
#Checking the overall number of null values in each and every column

mydata2.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## 4.<U>DATA CLEANING</U>:
# After we performed EDA , we found out that there was no null value in the Data File. The datatype was uniform throughout the Data File except "BARE NUCLEI". It's datatype was 'O' which represents object. We will further explore this column to confirm if there are any incorrect values present and accordingly decide what has to be done with such values. If the value would seem to not hamper the overall data then we would drop the particular column or else we would drop only those rows which would contain such values.

# %%
#Datatype of "Bare Nuclei" is 'O', inspite of having numerals. It was an incorrect datatype and the column was checked for incorrect values. It contained '?' literal, which was hampering the overall column.

mydata2['Bare Nuclei'].dtype
# Out:
# dtype('O')

# %%
#Checked for only those rows of the "Bare Nuclei" column that had '?' literal.

mydata2[mydata2["Bare Nuclei"] == "?"]
# Out:
#      Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 22              1057013                8                        4
# 39              1096800                6                        6
# 44              1103722                1                        1
# 125             1176881                7                        5
# 126             1177027                3                        1
# 138             1183246                1                        1
# 144             1184840                1                        1
# 157             1193683                1                        1
# 163             1197510                5                        1
# 234             1241232                3                        1
# 248              169356                3                        1
# 274              432809                3                        1
# 291              563649                8                        8
# ...

# %%
# Get names of indexes for which Column "Bare Nuclei" has '?' value

index_names = mydata2[ mydata2['Bare Nuclei'] == "?" ].index

#Drop these row indexes from dataframe

mydata2.drop(index_names, inplace = True)

# %%
#Check the datatype to verify if the rows having '?' values have been dropped.The Datatype is still the same.

mydata2['Bare Nuclei'].dtype
# Out:
# dtype('O')

# %%
#Check the rows having '?' values to get the confirmation.Such rows do not exist in the column. Values have been dropped successfully.

mydata2[mydata2["Bare Nuclei"] == "?"]
# Out:
# Empty DataFrame
# Columns: [Sample code number, Clump Thickness, Uniformity of Cell Size, Uniformity of Cell Shape, Marginal Adhesion, Single Epithelial Cell Size, Bare Nuclei, Bland Chromatin, Normal Nucleoli, Mitoses, Class]
# Index: []

# %%
#Convert the datatype to "int64"

mydata2["Bare Nuclei"] = mydata2["Bare Nuclei"].astype("int64")

# %%
#Check the datatype to confirm

mydata2['Bare Nuclei'].dtype
# Out:
# dtype('int64')

# %%
#Check the datatype of the entire dataframe once again. Bare Nuclei Column has been cleaned and corrected successfully.

mydata2.dtypes
# Out:
# Sample code number             int64
# Clump Thickness                int64
# Uniformity of Cell Size        int64
# Uniformity of Cell Shape       int64
# Marginal Adhesion              int64
# Single Epithelial Cell Size    int64
# Bare Nuclei                    int64
# Bland Chromatin                int64
# Normal Nucleoli                int64
# Mitoses                        int64
# Class                          int64
# dtype: object

# %%
#Dropping the "Sample code number" column as it is not required for the analysis or prediction purpose.
new_mydata2 = mydata2.drop(['Sample code number'], axis = 1)

# %%
#Check the dataframe, again, to cross check

new_mydata2

#"Sample code number" column has been dropped successfully. Data is well prepared to undergo Training and Testing.
# Out:
#      Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# 0                  5                        4                         4
# 1                  3                        1                         1
# 2                  6                        8                         8
# 3                  4                        1                         1
# 4                  8                       10                        10
# ..               ...                      ...                       ...
# 693                3                        1                         1
# 694                2                        1                         1
# 695                5                       10                        10
# 696                4                        8                         6
# 697                4                        8                         8
#
#      Marginal Adhesion  Single Epithelial Cell Size  Bare Nuclei  \
# ...

# %% [markdown]
# ## 5.<U>GRAPHICAL EDA USING SEABORN LIBRARY</U>:
# Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics. It is important to clean the data well before plotting it because values like '?','@','!'cannot be plotted and null values may obstruct the accuracy of the plot. Therefore, it is advisable to plot the Data after cleaning it well which will helps us in interpreting other ascpects of the data, well.

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#Scatter plot

sns.lmplot(x='Uniformity of Cell Size', y='Uniformity of Cell Shape', data=new_mydata2)

# %%
sns.lmplot(x='Uniformity of Cell Size', y='Uniformity of Cell Shape', data=new_mydata2 , fit_reg=False , hue='Class')

# %%
#Boxplot

new_dataf = new_mydata2.drop(['Class', 'Sample code number', 'Bare Nuclei','Mitoses'], axis=1)
sns.boxplot(data=new_dataf)
# Out:
# <AxesSubplot:>

# %%
#Horizontal box plots of the above.Vertical looked congested.

ax = sns.boxplot(data=new_dataf, orient="h", palette="Set2")

# %% [markdown]
# ### <U>VIOLIN PLOT</U>:
# Violin plots are useful alternatives to box plots.They show the distribution (through the thickness of the violin) instead of only the summary statistics.Violin plots are great for visualizing distributions.

# %%
#violin plot

sns.set_style('whitegrid') #setting the theme
sns.violinplot(x='Class', y='Uniformity of Cell Size', data=new_mydata2)
# Out:
# <AxesSubplot:xlabel='Class', ylabel='Uniformity of Cell Size'>

# %% [markdown]
# ### <U>HEATMAPS</U>:
# Heatmaps help you visualize matrix-like data.

# %%
#Calculate correlations

corr = new_mydata2.corr()
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### <U>JOINT DISTRIBUTION PLOT</U>:
# It combines information from scatter plots and histograms.

# %%
#Joint distribution plot

sns.jointplot(x='Clump Thickness', y='Single Epithelial Cell Size', data=new_mydata2)

# %% [markdown]
# ## 6.<U>SELECTING THE APPROPRIATE MODEL</U>:
# After Cleaning the Data and Exploratory Data Analysis, we will:
# 1. <u>Prepare the data</u>: In this, we will drop the column which has to be predicted and store this in a variable 'X'. We will initialize another variable 'y' with the column that has to be predicted( which we dropped out in the above step)
# 2. <u>Learning and Predicting using the MODEL</u>: In this, we will import the Logistic Regression model for predicting the 'Class' of the cancer. Logistic Regression is one of the Algorithm used in Supervised Machine learning technique. It is used for predicting the categorical dependent variable using a given set of independent variables.Therefore the outcome must be a categorical or discrete value. Hence, this model will be used in the prediction of the 'Class' of cancer.
# 3. <u>Calculating the Accuracy of the MODEL</u>: In this, we will import the train_test_split module and accuracy_score module for trainig/testing and calculating the accuracy of the data , respectively. The Data Set will be divided into training(80%) and testing(20%) sets and the input values for predictions will be compared to the testing data set , which will further be compared to the testing dataset of the column to be predicted and the accuracy of the model will be displayed.

# %%
#preparing the data

X = new_mydata2.drop(columns=['Class'])
y = new_mydata2['Class']

# %%
#Learning and Predicting

from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X , y)
predictions = model.predict([[4,3,3,4,6,9,2,1,2],[5,4,4,5,7,10,3,2,3],[6,5,5,6,8,9,2,3,2],[8,7,7,8,10,9,4,5,4],[9,8,8,9,10,8,5,4,5]])
predictions
# Out:
# array([4, 4, 4, 4, 4], dtype=int64)

# %%
#Calculating the accuracy

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X = new_mydata2.drop(columns=['Class'])
y = new_mydata2['Class']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

model = LogisticRegression()
model.fit(X_train, y_train)
predictions = model.predict(X_test)
score = accuracy_score(y_test, predictions)
score
# Out:
# 0.9852941176470589

# %% [markdown]
# ## 7.<U>RESULTS</U> :
# 1. Using the Logistic Regression Model of Supervised Machine Learning Technique, the 'Class' of Cancer was predicted to be **4(MALIGNANT)**.
# 2. The Accuracy of the Logistic Regression Model was calculated to be **98.52%**, which indicates that the selected model was best fit for the "Wisconsin Breast Cancer Database" and the prediction could be considered correct for the given input values.
